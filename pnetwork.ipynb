# %%
from dune_client.client import DuneClient
dune = DuneClient("rVRuwpjjYaD1yXJAVH3dVZufZcESZK4E")
query_result = dune.get_latest_result(4361022)

# %%
from dune_client.client import DuneClient
dune = DuneClient("rVRuwpjjYaD1yXJAVH3dVZufZcESZK4E")
query_result = dune.get_latest_result(4361022)

# %%
import pandas as pd
# 提取 rows 数据
rows = query_result.result.rows

# 创建 DataFrame
df = pd.DataFrame(rows)

# 如果需要，将 transaction_date 列转换为 datetime 类型
df['block_date'] = pd.to_datetime(df['block_date'])

# 查看 DataFrame
df
# Out:
#      arbitrum_trades  arbitrum_users  arbitrum_volume_usd  avalanche_trades  \
# 0                349              99         5.887281e+04                59
# 1               5369             189         3.507144e+06                70
# 2              79760             536         1.427031e+08              2484
# 3             136899             984         2.190559e+07               108
# 4               7920             180         2.871009e+05               131
# ..               ...             ...                  ...               ...
# 132                0               0                  NaN                 0
# 133                0               0                  NaN                 0
# 134                0               0                  NaN                 0
# 135                0               0                  NaN                 1
# 136                1               1         4.997234e-01                 2
#
#      avalanche_users  avalanche_volume_usd  base_trades  base_users  \
# 0                  1          4.416836e+03         2659           5
# 1                  3          7.774241e+03        17926          27
# 2                  2          5.377108e+06        19982          33
# 3                  0          1.088526e+05       113826           7
# 4                  0          1.728134e+05         8471          11
# ..               ...                   ...          ...         ...
# 132                0                   NaN            0           0
# 133                0                   NaN            0           0
# 134                0                   NaN            0           0
# 135                1          9.952071e-01            2           1
# 136                2          6.124390e-01            9           2
#
#      base_volume_usd  berachain_trades  ...  solana_trades  solana_users  \
# 0       3.753745e+05                16  ...           1797           730
# 1       3.678443e+06                62  ...           7928          1379
# 2       2.047967e+07                27  ...           4158           739
# 3       7.261507e+06                40  ...           1438           461
# 4       2.287403e+06                29  ...           1679           493
# ..               ...               ...  ...            ...           ...
# 132              NaN                 0  ...              7             4
# 133              NaN                 0  ...              7             4
# 134              NaN                 0  ...              4             3
# 135     3.995226e-01                 0  ...             20             7
# 136     2.727664e+01                 0  ...             25             7
#
#      solana_volume_usd sonic_trades  sonic_users  sonic_volume_usd  \
# 0         4.624384e+05           10            0       3016.871198
# 1         2.223955e+06           30            0      12740.214537
# 2         1.627076e+06          115            0      31835.700694
# 3         7.822808e+05           14            0       1563.794445
# 4         1.064857e+06           21            0       7372.752886
# ..                 ...          ...          ...               ...
# 132       5.131991e+01            0            0               NaN
# 133       1.405417e+01            0            0               NaN
# 134       1.331729e+02            0            0               NaN
# 135       3.313825e+03            0            0               NaN
# 136       1.947468e+01            0            0               NaN
#
#      total_fee_usd  total_trades  total_users  total_volume_usd
# 0     3.472359e+04         17549         1000      3.472359e+06
# 1     1.191495e+05         38088         1788      1.191495e+07
# 2     1.997137e+06        142402         1899      1.997137e+08
# 3     4.969482e+05        454113         1730      4.969482e+07
# 4     8.529439e+04         52612          921      8.529439e+06
# ..             ...           ...          ...               ...
# 132   1.694966e+00             8            4      1.694966e+02
# 133   1.405417e-01             7            4      1.405417e+01
# 134   2.353870e+00             8            3      2.353870e+02
# 135   3.318309e+01            27            7      3.318309e+03
# 136   9.543144e-01            52            7      9.543144e+01
#
# [137 rows x 41 columns]

# %%
df.to_csv('pnetwork.csv', index=False)
